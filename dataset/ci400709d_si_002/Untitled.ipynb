# %%
import pandas as pd

# %%
df = pd.read_csv('KIBA-Table 1.csv', index_col=[0])

# %%
df.describe()
# Out:
#            O00141     O00142     O00238      O00311       O00329      O00418  \
# count  136.000000  75.000000  75.000000  978.000000  1132.000000  445.000000
# mean     3.934125   4.091285   3.505149    2.257718     2.515398    3.548702
# std      0.752713   1.366507   0.902004    1.214375     1.354916    0.263062
# min      1.113943   1.494107  -0.070581   -1.154902    -0.913640    1.899985
# 25%      3.973128   2.969365   3.298848    1.397940     1.556303    3.600000
# 50%      4.000000   4.361728   4.000000    2.869408     2.434557    3.600000
# 75%      4.518514   5.363343   4.000000    3.100002     3.483922    3.600000
# max      5.096910   6.000000   4.060698    6.477121     7.600000    4.301030
#
#          O00443      O00444     O00506     O00750     ...          Q07002  \
# count  7.000000  792.000000  79.000000  86.000000     ...       80.000000
# mean   2.979069    3.130445   3.767354   3.610631     ...        3.735834
# ...

# %%
df.values.min(axis=1)
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
df.values.max(axis=1)
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])
